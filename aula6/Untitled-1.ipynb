# %%
idade = 18
if idade >= 18:
    print('Maior de idade')
else:
    print('menor de idade')
# Out:
# Maior de idade

# %%
print(idade * 2)
# Out:
# 36

# %% [markdown]
# 2. Laço While
# Repete um bloco de código enquanto a condição for verdadeira

# %%
contador = 0
while contador < 5:    
    print(f"Contador {contador}")
    contador = contador + 1
# Out:
# Contador 0
# Contador 1
# Contador 2
# Contador 3
# Contador 4

# %%
# While com break e continue
numero = 0

while True:
    numero = numero + 1
    # Pula números pares I
    if numero % 2 == 0:
         continue # Pula a execução da minha repetição, mas continua dentro do laço
    print (f"Número ímpar: {numero}")

    # Para o loop quando chegar a 10
    if numero >= 10:
          break # Sai do meu laço de repetição

# %%
# Simulação de jogo com while
import random

numero_secreto = random.randint(1, 100)
tentativas = 0

print("\nJogo de Adivinhação")
while True:
    tentativa = int(input("Escolha um número entre 1 e 10: "))
    tentativas += 1

    if tentativa == numero_secreto:
        print(f"Parabéns! Você acertou em {tentativas} tentativas. ")
        break
    elif tentativa < numero_secreto:
        print("Muito baixo. Tente novamente. ")
    else:
        print("Muito alto. Tente novamente. ")
# Out:
# Jogo de Adivinhação

# %%
frutas = ["maça", "banana", "laranja", "uva"]
print(len(frutas))

for fruta in frutas:
    print(f"Fruta: {fruta}")

# %%
# Iterando com enumerate
# frutas = [ .. . ]
print("\n Índices e valores :")
print("Valores em frutas: ", frutas)
for indice, fruta in enumerate(frutas):
    print(f"Iteração {indice + 1}: {fruta}")
# Out:
# nÍndices e valores :
# Valores em frutas:  ['maça', 'banana', 'laranja', 'uva']
# Iteração 1: maça
# Iteração 2: banana
# Iteração 3: laranja
# Iteração 4: uva

# %%
# For com else
numeros = [2, 4, 6, 8, 10]
busca = 8

for numero in numeros:
    print(f'indice: {numero}')#útil para procurar um valor dentro da lista
    if numero == busca:
        print(f"Número {busca} encontrado!")
        break
else:
    print (f"Número {busca} não encontrado.")
# Out:
# indice: 2
# indice: 4
# indice: 6
# indice: 8
# Número 8 encontrado!

# %%
# Compreensão de lista/list comprehension - cria uma lista de acordo com a condição que eu quero "Estudar list cmprehension"
quadrados = [x**2 for x in range(6)]
print("\nQuadrados:", quadrados)
# Out:
# Quadrados: [0, 1, 4, 9, 16, 25]
